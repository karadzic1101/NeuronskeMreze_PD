# %%
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from sklearn import datasets
from sklearn import model_selection
from sklearn import preprocessing 
from keras import losses, optimizers
import pandas as pn
import numpy as np

import matplotlib.pyplot as plt

# %matplotlib inline

# %%
data = pn.read_csv('pd.csv')
first = data[0:149]
f = pn.DataFrame.as_matrix(first)
f[np.argsort(f[:, 3])]
# Out:
# array([[  1.     ,  72.     ,   0.     , ...,   0.41888,   0.54842,
#           0.16006],
#        [  1.     ,  72.     ,   0.     , ...,   0.3734 ,   0.52499,
#           0.17066],
#        [  1.     ,  72.     ,   0.     , ...,   0.50911,   0.53637,
#           0.25183],
#        ...,
#        [  1.     ,  72.     ,   0.     , ...,   0.49219,   0.61602,
#           0.18939],
#        [  1.     ,  72.     ,   0.     , ...,   0.44728,   0.52472,
#           0.22185],
#        [  1.     ,  72.     ,   0.     , ...,   0.45109,   0.54152,
#           0.23613]])

# %%
shimmer = first['Shimmer(dB)']
time = first['test_time']
plt.xlabel("Test time")
plt.ylabel("Shimmer(dB)")
plt.plot(time, shimmer)

# %%
jitter = first['Jitter:PPQ5']
time = first['test_time']
plt.xlabel("Test time")
plt.ylabel("Jitter:PPQ5")
plt.plot(time, jitter)

# %%
ppe = first['PPE']
time = first['test_time']
plt.xlabel("Test time")
plt.ylabel("PPE")
plt.plot(time, ppe)
